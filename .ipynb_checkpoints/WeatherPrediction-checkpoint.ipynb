# %%
import pandas as pd

weather = pd.read_csv("weather.csv", index_col="DATE")

# %%
weather
# Out:
#                 STATION                                         NAME   ACMH  \
# DATE
# 1/1/1970    USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US   50.0
# 1/2/1970    USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  100.0
# 1/3/1970    USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US   80.0
# 1/4/1970    USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  100.0
# 1/5/1970    USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  100.0
# ...                 ...                                          ...    ...
# 12/24/2022  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US    NaN
# 12/25/2022  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US    NaN
# 12/26/2022  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US    NaN
# 12/27/2022  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US    NaN
# 12/28/2022  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US    NaN
#
#              ACSH  AWND  FMTM    PGTM  PRCP  PSUN  SNOW  ...  WT13  WT14  \
# DATE                                                     ...
# 1/1/1970     30.0   NaN   NaN  1600.0  0.00  81.0   0.0  ...   NaN   NaN
# 1/2/1970    100.0   NaN   NaN  1224.0  0.33   0.0   0.0  ...   NaN   NaN
# 1/3/1970     70.0   NaN   NaN   142.0  0.00  75.0   0.0  ...   NaN   NaN
# 1/4/1970    100.0   NaN   NaN  1442.0  0.69   0.0   0.0  ...   NaN   NaN
# 1/5/1970    100.0   NaN   NaN  2318.0  0.11   0.0   0.0  ...   NaN   NaN
# ...           ...   ...   ...     ...   ...   ...   ...  ...   ...   ...
# 12/24/2022    NaN  9.17   NaN     NaN  0.00   NaN   0.0  ...   NaN   NaN
# 12/25/2022    NaN  5.82   NaN     NaN  0.00   NaN   0.0  ...   NaN   NaN
# 12/26/2022    NaN  3.80   NaN     NaN  0.00   NaN   0.0  ...   NaN   NaN
# 12/27/2022    NaN  7.38   NaN   930.0  0.00   NaN   0.0  ...   NaN   NaN
# 12/28/2022    NaN   NaN   NaN     NaN  0.00   NaN   0.0  ...   NaN   NaN
#
#             WT15  WT16  WT17  WT18  WT19  WT21  WV03  WV20
# DATE
# 1/1/1970     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1/2/1970     NaN   1.0   NaN   NaN   NaN   NaN   NaN   NaN
# 1/3/1970     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1/4/1970     NaN   1.0   NaN   NaN   NaN   NaN   NaN   NaN
# 1/5/1970     NaN   1.0   NaN   NaN   NaN   NaN   NaN   NaN
# ...          ...   ...   ...   ...   ...   ...   ...   ...
# 12/24/2022   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 12/25/2022   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 12/26/2022   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 12/27/2022   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 12/28/2022   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [19355 rows x 47 columns]

# %%
null_pct = weather.apply(pd.isnull).sum()/weather.shape[0]

# %%
null_pct
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.510979
# ACSH       0.510979
# AWND       0.264479
# FMTM       0.473728
# PGTM       0.252441
# PRCP       0.000000
# PSUN       0.735831
# SNOW       0.166675
# SNWD       0.166417
# TAVG       0.677809
# TMAX       0.000000
# TMIN       0.000000
# TSUN       0.344665
# WDF1       0.636786
# WDF2       0.489331
# WDF5       0.490468
# WDFG       0.513046
# WDFM       0.874244
# WESD       0.698011
# WSF1       0.636786
# WSF2       0.489331
# WSF5       0.490261
# WSFG       0.512477
# WSFM       0.874244
# WT01       0.584397
# WT02       0.919969
# WT03       0.904262
# WT04       0.998657
# WT05       0.986722
# WT06       0.998088
# WT07       0.995402
# WT08       0.882614
# WT09       0.997623
# WT10       0.998915
# WT11       0.997830
# WT13       0.858538
# WT14       0.963575
# WT15       0.999328
# WT16       0.733299
# WT17       0.999535
# WT18       0.999277
# WT19       0.999845
# WT21       0.990390
# WV03       0.999897
# WV20       0.999845
# dtype: float64

# %%
valid_columns = weather.columns[null_pct < 0.05]

# %%
valid_columns
# Out:
# Index(['STATION', 'NAME', 'PRCP', 'TMAX', 'TMIN'], dtype='object')

# %%
weather = weather[valid_columns].copy()

# %%
weather.columns = weather.columns.str.lower()

# %%
weather
# Out:
#                 station                                         name  prcp  \
# DATE
# 1/1/1970    USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# 1/2/1970    USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.33
# 1/3/1970    USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# 1/4/1970    USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.69
# 1/5/1970    USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.11
# ...                 ...                                          ...   ...
# 12/24/2022  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# 12/25/2022  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# 12/26/2022  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# 12/27/2022  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# 12/28/2022  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
#
#             tmax  tmin
# DATE
# 1/1/1970      59    34
# 1/2/1970      56    43
# 1/3/1970      51    39
# 1/4/1970      55    40
# 1/5/1970      60    44
# ...          ...   ...
# 12/24/2022    40    24
# 12/25/2022    52    25
# 12/26/2022    66    28
# 12/27/2022    61    36
# 12/28/2022    79    44
#
# [19355 rows x 5 columns]

# %%
weather = weather.ffill()

# %%
weather.apply(pd.isnull).sum()
# Out:
# station    0
# name       0
# prcp       0
# tmax       0
# tmin       0
# dtype: int64

# %%
weather.dtypes
# Out:
# station     object
# name        object
# prcp       float64
# tmax         int64
# tmin         int64
# dtype: object

# %%
weather.index
# Out:
# Index(['1/1/1970', '1/2/1970', '1/3/1970', '1/4/1970', '1/5/1970', '1/6/1970',
#        '1/7/1970', '1/8/1970', '1/9/1970', '1/10/1970',
#        ...
#        '12/19/2022', '12/20/2022', '12/21/2022', '12/22/2022', '12/23/2022',
#        '12/24/2022', '12/25/2022', '12/26/2022', '12/27/2022', '12/28/2022'],
#       dtype='object', name='DATE', length=19355)

# %%
weather.index=pd.to_datetime(weather.index)

# %%
weather.index
# Out:
# DatetimeIndex(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04',
#                '1970-01-05', '1970-01-06', '1970-01-07', '1970-01-08',
#                '1970-01-09', '1970-01-10',
#                ...
#                '2022-12-19', '2022-12-20', '2022-12-21', '2022-12-22',
#                '2022-12-23', '2022-12-24', '2022-12-25', '2022-12-26',
#                '2022-12-27', '2022-12-28'],
#               dtype='datetime64[ns]', name='DATE', length=19355, freq=None)

# %%
weather.index.year.value_counts().sort_index()
# Out:
# 1970    365
# 1971    365
# 1972    366
# 1973    365
# 1974    365
# 1975    365
# 1976    366
# 1977    365
# 1978    365
# 1979    365
# 1980    366
# 1981    365
# 1982    365
# 1983    365
# 1984    366
# 1985    365
# 1986    365
# 1987    365
# 1988    366
# 1989    365
# 1990    365
# 1991    365
# 1992    366
# 1993    365
# 1994    365
# 1995    365
# 1996    366
# 1997    365
# 1998    365
# 1999    365
# 2000    366
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    366
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    362
# Name: DATE, dtype: int64

# %%
weather["prcp"].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
weather["target"] = weather.shift(-1)["tmax"]

# %%
weather
# Out:
#                 station                                         name  prcp  \
# DATE
# 1970-01-01  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# 1970-01-02  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.33
# 1970-01-03  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# 1970-01-04  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.69
# 1970-01-05  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.11
# ...                 ...                                          ...   ...
# 2022-12-24  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# 2022-12-25  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# 2022-12-26  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# 2022-12-27  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# 2022-12-28  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
#
#             tmax  tmin  target
# DATE
# 1970-01-01    59    34    56.0
# 1970-01-02    56    43    51.0
# 1970-01-03    51    39    55.0
# 1970-01-04    55    40    60.0
# 1970-01-05    60    44    44.0
# ...          ...   ...     ...
# 2022-12-24    40    24    52.0
# 2022-12-25    52    25    66.0
# 2022-12-26    66    28    61.0
# 2022-12-27    61    36    79.0
# 2022-12-28    79    44     NaN
#
# [19355 rows x 6 columns]

# %%
weather = weather.ffill()

# %%
from sklearn.linear_model import Ridge

rr = Ridge(alpha=.1)

# %%
predictors = weather.columns[~weather.columns.isin(["target","name","station"])]

# %%
predictors
# Out:
# Index(['prcp', 'tmax', 'tmin'], dtype='object')

# %%
def backtest(weather,model,predictors,start=3650,step=90):
    all_predictions=[]
    
    for i in range(start, weather.shape[0],step):
        train = weather.iloc[:i,:]
        test = weather.iloc[i:(i+step),:]
        
        model.fit(train[predictors], train["target"])
        
        preds = model.predict(test[predictors])
        
        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test["target"],preds], axis=1)
        
        combined.columns = ["actual", "prediction"]
        
        combined["diff"] = (combined["prediction"] - combined["actual"]).abs()
        
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(weather,rr,predictors)

# %%
predictions
# Out:
#             actual  prediction       diff
# DATE
# 1979-12-30    64.0   66.380939   2.380939
# 1979-12-31    69.0   65.582262   3.417738
# 1980-01-01    74.0   67.454420   6.545580
# 1980-01-02    65.0   73.319964   8.319964
# 1980-01-03    63.0   66.635569   3.635569
# ...            ...         ...        ...
# 2022-12-24    52.0   45.895754   6.104246
# 2022-12-25    66.0   54.341293  11.658707
# 2022-12-26    61.0   64.535659   3.535659
# 2022-12-27    79.0   62.583278  16.416722
# 2022-12-28    79.0   76.461429   2.538571
#
# [15705 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 4.145298511138562

# %%
def pct_diff(old, new):
    return (new - old) / old

def compute_rolling(weather, horizon, col):
    label = f"rolling_{horizon}_{col}"
    weather[label] = weather[col].rolling(horizon).mean()
    weather[f"{label}_pct"] = pct_diff(weather[label], weather[col])
    return weather
    
rolling_horizons = [3, 14]

for horizon in rolling_horizons:
    for col in ["tmax", "tmin", "prcp"]:
        weather = compute_rolling(weather, horizon, col)

# %%
weather
# Out:
#                 station                                         name  prcp  \
# DATE
# 1970-01-01  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# 1970-01-02  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.33
# 1970-01-03  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# 1970-01-04  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.69
# 1970-01-05  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.11
# ...                 ...                                          ...   ...
# 2022-12-24  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# 2022-12-25  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# 2022-12-26  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# 2022-12-27  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# 2022-12-28  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
#
#             tmax  tmin  target  rolling_3_tmax  rolling_3_tmax_pct  \
# DATE
# 1970-01-01    59    34    56.0             NaN                 NaN
# 1970-01-02    56    43    51.0             NaN                 NaN
# 1970-01-03    51    39    55.0       55.333333           -0.078313
# 1970-01-04    55    40    60.0       54.000000            0.018519
# 1970-01-05    60    44    44.0       55.333333            0.084337
# ...          ...   ...     ...             ...                 ...
# 2022-12-24    40    24    52.0       47.333333           -0.154930
# 2022-12-25    52    25    66.0       42.000000            0.238095
# 2022-12-26    66    28    61.0       52.666667            0.253165
# 2022-12-27    61    36    79.0       59.666667            0.022346
# 2022-12-28    79    44    79.0       68.666667            0.150485
#
#             rolling_3_tmin  rolling_3_tmin_pct  rolling_3_prcp  \
# DATE
# 1970-01-01             NaN                 NaN             NaN
# 1970-01-02             NaN                 NaN             NaN
# 1970-01-03       38.666667            0.008621        0.110000
# 1970-01-04       40.666667           -0.016393        0.340000
# 1970-01-05       41.000000            0.073171        0.266667
# ...                    ...                 ...             ...
# 2022-12-24       24.000000            0.000000        0.000000
# 2022-12-25       23.666667            0.056338        0.000000
# 2022-12-26       25.666667            0.090909        0.000000
# 2022-12-27       29.666667            0.213483        0.000000
# 2022-12-28       36.000000            0.222222        0.000000
#
#             rolling_3_prcp_pct  rolling_14_tmax  rolling_14_tmax_pct  \
# DATE
# 1970-01-01                 NaN              NaN                  NaN
# 1970-01-02                 NaN              NaN                  NaN
# 1970-01-03           -1.000000              NaN                  NaN
# 1970-01-04            1.029412              NaN                  NaN
# 1970-01-05           -0.587500              NaN                  NaN
# ...                        ...              ...                  ...
# 2022-12-24                 NaN        64.428571            -0.379157
# 2022-12-25                 NaN        62.357143            -0.166094
# 2022-12-26                 NaN        61.285714             0.076923
# 2022-12-27                 NaN        59.571429             0.023981
# 2022-12-28                 NaN        59.857143             0.319809
#
#             rolling_14_tmin  rolling_14_tmin_pct  rolling_14_prcp  \
# DATE
# 1970-01-01              NaN                  NaN              NaN
# 1970-01-02              NaN                  NaN              NaN
# 1970-01-03              NaN                  NaN              NaN
# 1970-01-04              NaN                  NaN              NaN
# 1970-01-05              NaN                  NaN              NaN
# ...                     ...                  ...              ...
# 2022-12-24        47.428571            -0.493976         0.015000
# 2022-12-25        44.428571            -0.437299         0.015000
# 2022-12-26        41.428571            -0.324138         0.015000
# 2022-12-27        39.000000            -0.076923         0.015000
# 2022-12-28        38.571429             0.140741         0.014286
#
#             rolling_14_prcp_pct
# DATE
# 1970-01-01                  NaN
# 1970-01-02                  NaN
# 1970-01-03                  NaN
# 1970-01-04                  NaN
# 1970-01-05                  NaN
# ...                         ...
# 2022-12-24                 -1.0
# 2022-12-25                 -1.0
# 2022-12-26                 -1.0
# 2022-12-27                 -1.0
# 2022-12-28                 -1.0
#
# [19355 rows x 18 columns]

# %%
weather = weather.iloc[14:,:]

# %%
weather
# Out:
#                 station                                         name  prcp  \
# DATE
# 1970-01-15  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# 1970-01-16  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.16
# 1970-01-17  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# 1970-01-18  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# 1970-01-19  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# ...                 ...                                          ...   ...
# 2022-12-24  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# 2022-12-25  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# 2022-12-26  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# 2022-12-27  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# 2022-12-28  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
#
#             tmax  tmin  target  rolling_3_tmax  rolling_3_tmax_pct  \
# DATE
# 1970-01-15    61    39    64.0       53.666667            0.136646
# 1970-01-16    64    53    65.0       58.000000            0.103448
# 1970-01-17    65    45    54.0       63.333333            0.026316
# 1970-01-18    54    35    51.0       61.000000           -0.114754
# 1970-01-19    51    33    66.0       56.666667           -0.100000
# ...          ...   ...     ...             ...                 ...
# 2022-12-24    40    24    52.0       47.333333           -0.154930
# 2022-12-25    52    25    66.0       42.000000            0.238095
# 2022-12-26    66    28    61.0       52.666667            0.253165
# 2022-12-27    61    36    79.0       59.666667            0.022346
# 2022-12-28    79    44    79.0       68.666667            0.150485
#
#             rolling_3_tmin  rolling_3_tmin_pct  rolling_3_prcp  \
# DATE
# 1970-01-15       41.000000           -0.048780        0.103333
# 1970-01-16       44.333333            0.195489        0.073333
# 1970-01-17       45.666667           -0.014599        0.053333
# 1970-01-18       44.333333           -0.210526        0.053333
# 1970-01-19       37.666667           -0.123894        0.000000
# ...                    ...                 ...             ...
# 2022-12-24       24.000000            0.000000        0.000000
# 2022-12-25       23.666667            0.056338        0.000000
# 2022-12-26       25.666667            0.090909        0.000000
# 2022-12-27       29.666667            0.213483        0.000000
# 2022-12-28       36.000000            0.222222        0.000000
#
#             rolling_3_prcp_pct  rolling_14_tmax  rolling_14_tmax_pct  \
# DATE
# 1970-01-15           -1.000000        53.071429             0.149394
# 1970-01-16            1.181818        53.642857             0.193076
# 1970-01-17           -1.000000        54.642857             0.189542
# 1970-01-18           -1.000000        54.571429            -0.010471
# 1970-01-19                 NaN        53.928571            -0.054305
# ...                        ...              ...                  ...
# 2022-12-24                 NaN        64.428571            -0.379157
# 2022-12-25                 NaN        62.357143            -0.166094
# 2022-12-26                 NaN        61.285714             0.076923
# 2022-12-27                 NaN        59.571429             0.023981
# 2022-12-28                 NaN        59.857143             0.319809
#
#             rolling_14_tmin  rolling_14_tmin_pct  rolling_14_prcp  \
# DATE
# 1970-01-15        39.000000             0.000000         0.106429
# 1970-01-16        39.714286             0.334532         0.094286
# 1970-01-17        40.142857             0.120996         0.094286
# 1970-01-18        39.785714            -0.120287         0.045000
# 1970-01-19        39.000000            -0.153846         0.037143
# ...                     ...                  ...              ...
# 2022-12-24        47.428571            -0.493976         0.015000
# 2022-12-25        44.428571            -0.437299         0.015000
# 2022-12-26        41.428571            -0.324138         0.015000
# 2022-12-27        39.000000            -0.076923         0.015000
# 2022-12-28        38.571429             0.140741         0.014286
#
#             rolling_14_prcp_pct
# DATE
# 1970-01-15             -1.00000
# 1970-01-16              0.69697
# 1970-01-17             -1.00000
# 1970-01-18             -1.00000
# 1970-01-19             -1.00000
# ...                         ...
# 2022-12-24             -1.00000
# 2022-12-25             -1.00000
# 2022-12-26             -1.00000
# 2022-12-27             -1.00000
# 2022-12-28             -1.00000
#
# [19341 rows x 18 columns]

# %%
weather = weather.fillna(0)

# %%
def expand_mean(df):
    return df.expanding(1).mean()

for col in ["tmax", "tmin", "prcp"]:
    weather[f"month_avg_{col}"] = weather[col].groupby(weather.index.month, group_keys=False).apply(expand_mean)
    weather[f"day_avg_{col}"] = weather[col].groupby(weather.index.day_of_year, group_keys=False).apply(expand_mean)

# %%
weather
# Out:
#                 station                                         name  prcp  \
# DATE
# 1970-01-15  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# 1970-01-16  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.16
# 1970-01-17  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# 1970-01-18  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# 1970-01-19  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# ...                 ...                                          ...   ...
# 2022-12-24  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# 2022-12-25  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# 2022-12-26  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# 2022-12-27  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
# 2022-12-28  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  0.00
#
#             tmax  tmin  target  rolling_3_tmax  rolling_3_tmax_pct  \
# DATE
# 1970-01-15    61    39    64.0       53.666667            0.136646
# 1970-01-16    64    53    65.0       58.000000            0.103448
# 1970-01-17    65    45    54.0       63.333333            0.026316
# 1970-01-18    54    35    51.0       61.000000           -0.114754
# 1970-01-19    51    33    66.0       56.666667           -0.100000
# ...          ...   ...     ...             ...                 ...
# 2022-12-24    40    24    52.0       47.333333           -0.154930
# 2022-12-25    52    25    66.0       42.000000            0.238095
# 2022-12-26    66    28    61.0       52.666667            0.253165
# 2022-12-27    61    36    79.0       59.666667            0.022346
# 2022-12-28    79    44    79.0       68.666667            0.150485
#
#             rolling_3_tmin  rolling_3_tmin_pct  ...  rolling_14_tmin  \
# DATE                                            ...
# 1970-01-15       41.000000           -0.048780  ...        39.000000
# 1970-01-16       44.333333            0.195489  ...        39.714286
# 1970-01-17       45.666667           -0.014599  ...        40.142857
# 1970-01-18       44.333333           -0.210526  ...        39.785714
# 1970-01-19       37.666667           -0.123894  ...        39.000000
# ...                    ...                 ...  ...              ...
# 2022-12-24       24.000000            0.000000  ...        47.428571
# 2022-12-25       23.666667            0.056338  ...        44.428571
# 2022-12-26       25.666667            0.090909  ...        41.428571
# 2022-12-27       29.666667            0.213483  ...        39.000000
# 2022-12-28       36.000000            0.222222  ...        38.571429
#
#             rolling_14_tmin_pct  rolling_14_prcp  rolling_14_prcp_pct  \
# DATE
# 1970-01-15             0.000000         0.106429             -1.00000
# 1970-01-16             0.334532         0.094286              0.69697
# 1970-01-17             0.120996         0.094286             -1.00000
# 1970-01-18            -0.120287         0.045000             -1.00000
# 1970-01-19            -0.153846         0.037143             -1.00000
# ...                         ...              ...                  ...
# 2022-12-24            -0.493976         0.015000             -1.00000
# 2022-12-25            -0.437299         0.015000             -1.00000
# 2022-12-26            -0.324138         0.015000             -1.00000
# 2022-12-27            -0.076923         0.015000             -1.00000
# 2022-12-28             0.140741         0.014286             -1.00000
#
#             month_avg_tmax  day_avg_tmax  month_avg_tmin  day_avg_tmin  \
# DATE
# 1970-01-15       61.000000     61.000000       39.000000     39.000000
# 1970-01-16       62.500000     64.000000       46.000000     53.000000
# 1970-01-17       63.333333     65.000000       45.666667     45.000000
# 1970-01-18       61.000000     54.000000       43.000000     35.000000
# 1970-01-19       59.000000     51.000000       41.000000     33.000000
# ...                    ...           ...             ...           ...
# 2022-12-24       69.365526     66.660377       49.259780     46.584906
# 2022-12-25       69.354918     65.301887       49.244960     44.433962
# 2022-12-26       69.352869     66.433962       49.231990     45.433962
# 2022-12-27       69.347773     68.037736       49.223917     46.849057
# 2022-12-28       69.353659     69.264151       49.220732     49.207547
#
#             month_avg_prcp  day_avg_prcp
# DATE
# 1970-01-15        0.000000      0.000000
# 1970-01-16        0.080000      0.160000
# 1970-01-17        0.053333      0.000000
# 1970-01-18        0.040000      0.000000
# 1970-01-19        0.032000      0.000000
# ...                    ...           ...
# 2022-12-24        0.051271      0.038868
# 2022-12-25        0.051240      0.018679
# 2022-12-26        0.051209      0.057170
# 2022-12-27        0.051178      0.029434
# 2022-12-28        0.051146      0.073019
#
# [19341 rows x 24 columns]

# %%
predictors = weather.columns[~weather.columns.isin(["target","name","station"])]

# %%
predictors
# Out:
# Index(['prcp', 'tmax', 'tmin', 'rolling_3_tmax', 'rolling_3_tmax_pct',
#        'rolling_3_tmin', 'rolling_3_tmin_pct', 'rolling_3_prcp',
#        'rolling_3_prcp_pct', 'rolling_14_tmax', 'rolling_14_tmax_pct',
#        'rolling_14_tmin', 'rolling_14_tmin_pct', 'rolling_14_prcp',
#        'rolling_14_prcp_pct', 'month_avg_tmax', 'day_avg_tmax',
#        'month_avg_tmin', 'day_avg_tmin', 'month_avg_prcp', 'day_avg_prcp'],
#       dtype='object')

# %%
predictions = backtest(weather, rr, predictors)

# %%
mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 3.856424462906606

# %%
predictions.sort_values("diff", ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 1990-12-21    38.0   77.810410  39.810410
# 1989-12-15    35.0   70.463467  35.463467
# 2022-12-22    34.0   68.932394  34.932394
# 2019-11-11    42.0   75.217884  33.217884
# 2014-01-23    40.0   72.793916  32.793916
# ...            ...         ...        ...
# 1990-07-02    95.0   95.000812   0.000812
# 1980-09-05    92.0   91.999582   0.000418
# 1993-08-09    95.0   95.000374   0.000374
# 2009-08-09    98.0   97.999691   0.000309
# 1992-07-13    92.0   91.999871   0.000129
#
# [15691 rows x 3 columns]

# %%
predictions["diff"].round().value_counts().sort_index().plot()
# Out:
# <AxesSubplot:>
